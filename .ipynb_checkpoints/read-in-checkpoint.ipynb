# %%
import os, glob

import tensorflow as tf
import tiffile as tif

# %%
DIR = 'data/koeln'

# %%
def parse_image(img_path: str) -> dict:   
    
    image = tf.convert_to_tensor(plt.imread(img_path).astype(np.float32))
    
    mask_path = img_path.replace('rgb.png', 'seg.tif')
    mask = tf.convert_to_tensor(tif.imread(mask_path).astype(np.int32))
    
    return {'image': image, 'segmentation_mask': mask}

# %% [raw]
# # convert .jp2 files to .png; run only once
# from PIL import Image
#
# for file in os.listdir(DIR):
#     if file.endswith(".jp2"):
#         img = Image.open(os.path.join(DIR,file))
#         img.save(os.path.join(DIR,file[0:-4] + ".png"))

# %%
files = glob.glob(os.path.join(DIR,"*_rgb.png"))

SIZE = len(files)

geonrw = tf.data.Dataset.list_files(files)
geonrw = geonrw.shuffle(SIZE)
geonrw = geonrw.map(parse_image)

# %%
def parse_image_2(img_path: str) -> dict:
    image = tf.io.read_file(img_path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.uint8)

    mask_path = tf.strings.regex_replace(img_path, "rgb.png", "seg.tif")
    mask = tf.io.read_file(mask_path)
    mask = tfio.experimental.image.decode_tiff(mask)

    return {'image': image, 'segmentation_mask': mask}

# %%
files = glob.glob(os.path.join(DIR,"*_rgb.png"))

files
# Out:
# []

# %%
os.listdir(DIR)
# Out:
# ['357_5655_dem.tif',
#  '369_5639_seg.tif',
#  '366_5642_dem.tif',
#  '352_5659_dem.tif',
#  '351_5654_dem.tif',
#  '349_5652_seg.tif',
#  '362_5634_seg.tif',
#  '362_5647_seg.tif',
#  '355_5656_rgb.jp2',
#  '353_5652_seg.tif',
#  '360_5637_dem.tif',
#  '359_5647_dem.tif',
#  '347_5660_seg.tif',
#  '346_5647_seg.tif',
#  '345_5659_seg.tif',
#  '347_5659_rgb.jp2',
#  '354_5633_seg.tif',
#  '369_5642_seg.tif',
#  '357_5642_dem.tif',
#  '366_5639_rgb.jp2',
#  '353_5647_seg.tif',
#  '368_5638_dem.tif',
#  '366_5647_seg.tif',
#  '347_5660_rgb.jp2',
#  '354_5657_dem.tif',
#  '356_5634_rgb.jp2',
#  '351_5659_dem.tif',
#  '350_5654_rgb.jp2',
#  '348_5651_dem.tif',
#  '343_5658_rgb.jp2',
#  '355_5656_dem.tif',
#  '369_5645_dem.tif',
#  '350_5641_seg.tif',
#  '349_5647_rgb.jp2',
#  '352_5650_seg.tif',
#  '357_5645_rgb.jp2',
#  '361_5639_seg.tif',
#  '364_5634_rgb.jp2',
#  '348_5659_rgb.jp2',
#  '355_5647_seg.tif',
#  '354_5639_dem.tif',
#  '356_5656_rgb.jp2',
#  '365_5641_dem.tif',
#  '364_5638_dem.tif',
#  '361_5640_rgb.jp2',
#  '350_5642_rgb.jp2',
#  '365_5643_seg.tif',
#  '355_5639_seg.tif',
#  '346_5656_rgb.jp2',
#  '346_5646_dem.tif',
#  '369_5638_rgb.jp2',
#  '369_5639_rgb.jp2',
#  '361_5649_rgb.jp2',
#  '354_5636_dem.tif',
#  '361_5651_rgb.jp2',
#  '357_5653_rgb.jp2',
#  '361_5635_seg.tif',
#  '359_5636_rgb.jp2',
#  '354_5653_dem.tif',
#  '368_5634_seg.tif',
#  '355_5647_rgb.jp2',
#  '356_5651_rgb.jp2',
#  '361_5650_seg.tif',
#  '351_5659_seg.tif',
#  '351_5657_dem.tif',
#  '362_5654_dem.tif',
#  '362_5646_seg.tif',
#  '347_5648_seg.tif',
#  '352_5648_seg.tif',
#  '344_5658_dem.tif',
#  '352_5658_dem.tif',
#  '349_5655_dem.tif',
#  '360_5649_seg.tif',
#  '351_5646_seg.tif',
#  '349_5654_seg.tif',
#  '350_5646_seg.tif',
#  '366_5634_seg.tif',
#  '354_5642_dem.tif',
#  '365_5645_seg.tif',
#  '365_5646_seg.tif',
#  '364_5652_seg.tif',
#  '368_5634_rgb.jp2',
#  '360_5652_dem.tif',
#  '353_5654_seg.tif',
#  '350_5649_dem.tif',
#  '361_5651_seg.tif',
#  '350_5653_dem.tif',
#  '361_5644_dem.tif',
#  '357_5649_seg.tif',
#  '353_5645_seg.tif',
#  '354_5649_dem.tif',
#  '364_5646_seg.tif',
#  '363_5637_rgb.jp2',
#  '349_5658_rgb.jp2',
#  '347_5655_rgb.jp2',
#  '347_5657_dem.tif',
#  '354_5638_rgb.jp2',
#  '365_5650_rgb.jp2',
#  '349_5641_dem.tif',
#  '356_5640_rgb.jp2',
#  '357_5649_dem.tif',
#  '354_5644_rgb.jp2',
#  '359_5652_seg.tif',
#  '348_5658_dem.tif',
#  '362_5648_seg.tif',
#  '357_5650_dem.tif',
#  '360_5636_dem.tif',
#  '367_5643_seg.tif',
#  '343_5659_rgb.jp2',
#  '351_5643_seg.tif',
#  '357_5654_dem.tif',
#  '365_5647_dem.tif',
#  '362_5653_dem.tif',
#  '343_5658_seg.tif',
#  '356_5654_dem.tif',
#  '351_5647_rgb.jp2',
#  '358_5637_rgb.jp2',
#  '364_5634_seg.tif',
#  '354_5655_rgb.jp2',
#  '364_5636_dem.tif',
#  '352_5645_dem.tif',
#  '349_5656_seg.tif',
#  '361_5646_dem.tif',
#  '363_5634_seg.tif',
#  '350_5643_dem.tif',
#  '367_5634_dem.tif',
#  '367_5641_rgb.jp2',
#  '364_5644_dem.tif',
#  '359_5653_rgb.jp2',
#  '350_5643_seg.tif',
#  '349_5645_rgb.jp2',
#  '353_5643_dem.tif',
#  '345_5657_seg.tif',
#  '365_5648_seg.tif',
#  '361_5636_seg.tif',
#  '368_5642_dem.tif',
#  '355_5641_dem.tif',
#  '355_5640_seg.tif',
#  '353_5655_seg.tif',
#  '356_5633_rgb.jp2',
#  '354_5644_seg.tif',
#  '365_5643_dem.tif',
#  '363_5642_rgb.jp2',
#  '363_5644_rgb.jp2',
#  '365_5633_rgb.jp2',
#  '354_5637_seg.tif',
#  '351_5644_dem.tif',
#  '356_5641_dem.tif',
#  '357_5645_seg.tif',
#  '351_5655_seg.tif',
#  '353_5653_rgb.jp2',
#  '348_5656_dem.tif',
#  '362_5647_rgb.jp2',
#  '360_5646_seg.tif',
#  '357_5634_seg.tif',
#  '350_5652_rgb.jp2',
#  '355_5651_seg.tif',
#  '363_5644_dem.tif',
#  '354_5656_rgb.jp2',
#  '356_5634_dem.tif',
#  '359_5646_seg.tif',
#  '362_5648_rgb.jp2',
#  '356_5647_rgb.jp2',
#  '358_5640_rgb.jp2',
#  '362_5640_rgb.jp2',
#  '353_5638_rgb.jp2',
#  '363_5636_rgb.jp2',
#  '363_5640_rgb.jp2',
#  '356_5633_seg.tif',
#  '352_5645_seg.tif',
#  '354_5639_rgb.jp2',
#  '354_5657_seg.tif',
#  '360_5650_dem.tif',
#  '352_5654_seg.tif',
#  '363_5649_seg.tif',
#  '364_5642_dem.tif',
#  '367_5636_rgb.jp2',
#  '364_5635_rgb.jp2',
#  '364_5635_dem.tif',
#  '353_5643_seg.tif',
#  '353_5651_seg.tif',
#  '357_5648_rgb.jp2',
#  '345_5658_seg.tif',
#  '358_5647_dem.tif',
#  '351_5646_dem.tif',
#  '360_5644_dem.tif',
#  '357_5651_dem.tif',
#  '350_5651_rgb.jp2',
#  '357_5637_seg.tif',
#  '361_5643_rgb.jp2',
#  '361_5645_rgb.jp2',
#  '356_5655_seg.tif',
#  '363_5633_dem.tif',
#  '361_5650_rgb.jp2',
#  '352_5656_dem.tif',
#  '366_5649_dem.tif',
#  '365_5640_dem.tif',
#  '360_5654_dem.tif',
#  '347_5649_seg.tif',
#  '353_5637_seg.tif',
#  '364_5647_rgb.jp2',
#  '354_5652_seg.tif',
#  '358_5634_rgb.jp2',
#  '358_5638_seg.tif',
#  '359_5639_rgb.jp2',
#  '349_5654_rgb.jp2',
#  '369_5636_rgb.jp2',
#  '363_5651_rgb.jp2',
#  '353_5647_rgb.jp2',
#  '367_5645_rgb.jp2',
#  '363_5632_rgb.jp2',
#  '357_5641_dem.tif',
#  '363_5648_rgb.jp2',
#  '359_5648_seg.tif',
#  '364_5653_dem.tif',
#  '362_5635_seg.tif',
#  '362_5654_rgb.jp2',
#  '362_5638_seg.tif',
#  '360_5633_rgb.jp2',
#  '353_5641_seg.tif',
#  '352_5640_seg.tif',
#  '361_5647_seg.tif',
#  '359_5638_rgb.jp2',
#  '352_5655_dem.tif',
#  '357_5634_rgb.jp2',
#  '358_5633_dem.tif',
#  '360_5634_dem.tif',
#  '348_5657_rgb.jp2',
#  '353_5634_rgb.jp2',
#  '354_5633_dem.tif',
#  '365_5650_seg.tif',
#  '368_5640_dem.tif',
#  '353_5656_rgb.jp2',
#  '363_5653_rgb.jp2',
#  '364_5640_dem.tif',
#  '359_5637_dem.tif',
#  '363_5647_dem.tif',
#  '353_5656_dem.tif',
#  '350_5653_seg.tif',
#  '352_5650_dem.tif',
#  '348_5652_seg.tif',
#  '364_5641_seg.tif',
#  '364_5639_seg.tif',
#  '349_5641_rgb.jp2',
#  '367_5638_dem.tif',
#  '350_5641_rgb.jp2',
#  '353_5636_dem.tif',
#  '359_5640_rgb.jp2',
#  '346_5657_rgb.jp2',
#  '353_5635_seg.tif',
#  '363_5635_dem.tif',
#  '355_5655_seg.tif',
#  '348_5653_rgb.jp2',
#  '357_5647_rgb.jp2',
#  '364_5652_dem.tif',
#  '361_5644_rgb.jp2',
#  '361_5643_seg.tif',
#  '349_5647_seg.tif',
#  '367_5637_rgb.jp2',
#  '359_5636_seg.tif',
#  '349_5648_seg.tif',
#  '362_5646_dem.tif',
#  '360_5639_dem.tif',
#  '358_5635_dem.tif',
#  '370_5636_rgb.jp2',
#  '366_5637_seg.tif',
#  '353_5640_rgb.jp2',
#  '348_5649_seg.tif',
#  '365_5638_seg.tif',
#  '349_5641_seg.tif',
#  '353_5636_seg.tif',
#  '347_5645_rgb.jp2',
#  '350_5660_rgb.jp2',
#  '357_5652_dem.tif',
#  '346_5648_dem.tif',
#  '347_5645_dem.tif',
#  '362_5648_dem.tif',
#  '358_5634_seg.tif',
#  '348_5641_dem.tif',
#  '368_5643_seg.tif',
#  '359_5646_rgb.jp2',
#  '348_5654_rgb.jp2',
#  '356_5635_dem.tif',
#  '358_5646_seg.tif',
#  '348_5656_rgb.jp2',
#  '368_5637_seg.tif',
#  '364_5636_seg.tif',
#  '346_5646_seg.tif',
#  '347_5645_seg.tif',
#  '346_5658_dem.tif',
#  '356_5655_rgb.jp2',
#  '355_5652_rgb.jp2',
#  '357_5655_rgb.jp2',
#  '345_5645_seg.tif',
#  '358_5643_dem.tif',
#  '355_5646_seg.tif',
#  '365_5641_seg.tif',
#  '355_5636_rgb.jp2',
#  '365_5637_seg.tif',
#  '368_5643_rgb.jp2',
#  '366_5635_seg.tif',
#  '359_5635_dem.tif',
#  '345_5656_seg.tif',
#  '366_5644_seg.tif',
#  '366_5637_rgb.jp2',
#  '358_5642_rgb.jp2',
#  '366_5643_seg.tif',
#  '360_5654_rgb.jp2',
#  '356_5650_rgb.jp2',
#  '363_5639_rgb.jp2',
#  '350_5648_rgb.jp2',
#  '357_5642_seg.tif',
#  '359_5651_seg.tif',
#  '360_5633_dem.tif',
#  '353_5640_dem.tif',
#  '364_5644_seg.tif',
#  '364_5649_rgb.jp2',
#  '353_5634_dem.tif',
#  '361_5648_rgb.jp2',
#  '361_5646_seg.tif',
#  '365_5649_rgb.jp2',
#  '358_5649_rgb.jp2',
#  '354_5653_rgb.jp2',
#  '357_5650_seg.tif',
#  '366_5645_rgb.jp2',
#  '365_5648_rgb.jp2',
#  '368_5639_rgb.jp2',
#  '360_5635_rgb.jp2',
#  '362_5641_seg.tif',
#  '362_5643_rgb.jp2',
#  '353_5637_rgb.jp2',
#  '352_5651_dem.tif',
#  '357_5651_seg.tif',
#  '358_5639_dem.tif',
#  '351_5643_rgb.jp2',
#  '370_5636_dem.tif',
#  '361_5652_seg.tif',
#  '350_5659_rgb.jp2',
#  '354_5658_dem.tif',
#  '365_5639_seg.tif',
#  '360_5650_rgb.jp2',
#  '364_5644_rgb.jp2',
#  '358_5645_dem.tif',
#  '356_5647_dem.tif',
#  '350_5656_seg.tif',
#  '362_5638_rgb.jp2',
#  '364_5638_rgb.jp2',
#  '346_5647_rgb.jp2',
#  '356_5643_rgb.jp2',
#  '365_5632_seg.tif',
#  '362_5637_rgb.jp2',
#  '364_5652_rgb.jp2',
#  '358_5640_dem.tif',
#  '349_5654_dem.tif',
#  '358_5653_seg.tif',
#  '364_5645_rgb.jp2',
#  '353_5655_rgb.jp2',
#  '360_5642_rgb.jp2',
#  '354_5658_seg.tif',
#  '358_5639_rgb.jp2',
#  '355_5656_seg.tif',
#  '356_5641_rgb.jp2',
#  '367_5635_seg.tif',
#  '349_5656_dem.tif',
#  '354_5638_dem.tif',
#  '347_5658_seg.tif',
#  '364_5637_seg.tif',
#  '368_5636_dem.tif',
#  '358_5637_dem.tif',
#  '349_5644_seg.tif',
#  '351_5649_seg.tif',
#  '365_5646_dem.tif',
#  '353_5648_seg.tif',
#  '364_5650_seg.tif',
#  '366_5649_seg.tif',
#  '366_5634_rgb.jp2',
#  '356_5654_seg.tif',
#  '354_5648_rgb.jp2',
#  '367_5638_seg.tif',
#  '353_5650_seg.tif',
#  '363_5647_rgb.jp2',
#  '354_5638_seg.tif',
#  '359_5633_seg.tif',
#  '353_5658_rgb.jp2',
#  '348_5660_seg.tif',
#  '355_5648_rgb.jp2',
#  '364_5649_dem.tif',
#  '348_5650_dem.tif',
#  '348_5641_seg.tif',
#  '367_5633_seg.tif',
#  '348_5643_rgb.jp2',
#  '351_5646_rgb.jp2',
#  '359_5644_rgb.jp2',
#  '352_5644_seg.tif',
#  '364_5632_dem.tif',
#  '354_5637_dem.tif',
#  '366_5638_dem.tif',
#  '349_5650_dem.tif',
#  '350_5642_seg.tif',
#  '350_5644_seg.tif',
#  '348_5655_seg.tif',
#  '350_5655_rgb.jp2',
#  '353_5644_rgb.jp2',
#  '369_5643_dem.tif',
#  '358_5652_rgb.jp2',
#  '366_5638_rgb.jp2',
#  '365_5639_dem.tif',
#  '362_5636_rgb.jp2',
#  '366_5643_dem.tif',
#  '361_5641_seg.tif',
#  '348_5648_seg.tif',
#  '359_5642_dem.tif',
#  '348_5642_seg.tif',
#  '348_5647_dem.tif',
#  '352_5653_seg.tif',
#  '353_5657_seg.tif',
#  '361_5646_rgb.jp2',
#  '358_5636_seg.tif',
#  '349_5659_seg.tif',
#  '350_5659_seg.tif',
#  '352_5649_rgb.jp2',
#  '348_5657_dem.tif',
#  '354_5642_seg.tif',
#  '352_5648_dem.tif',
#  '361_5647_dem.tif',
#  '352_5642_dem.tif',
#  '361_5637_rgb.jp2',
#  '351_5644_seg.tif',
#  '352_5647_rgb.jp2',
#  '354_5646_dem.tif',
#  '351_5644_rgb.jp2',
#  '351_5648_dem.tif',
#  '352_5652_rgb.jp2',
#  '357_5639_seg.tif',
#  '356_5655_dem.tif',
#  '368_5641_seg.tif',
#  '350_5641_dem.tif',
#  '358_5642_dem.tif',
#  '363_5649_rgb.jp2',
#  '359_5643_dem.tif',
#  '368_5638_seg.tif',
#  '363_5650_seg.tif',
#  '357_5634_dem.tif',
#  '356_5635_seg.tif',
#  '363_5633_seg.tif',
#  '368_5637_rgb.jp2',
#  '347_5647_dem.tif',
#  '363_5646_dem.tif',
#  '358_5635_rgb.jp2',
#  '359_5647_seg.tif',
#  '368_5638_rgb.jp2',
#  '348_5661_rgb.jp2',
#  '354_5652_rgb.jp2',
#  '356_5639_dem.tif',
#  '364_5632_seg.tif',
#  '360_5646_rgb.jp2',
#  '348_5651_rgb.jp2',
#  '348_5645_seg.tif',
#  '366_5635_dem.tif',
#  '366_5645_seg.tif',
#  '355_5655_rgb.jp2',
#  '364_5648_rgb.jp2',
#  '356_5651_seg.tif',
#  '365_5635_seg.tif',
#  '350_5650_dem.tif',
#  '365_5645_dem.tif',
#  '367_5636_dem.tif',
#  '369_5641_rgb.jp2',
#  '349_5651_rgb.jp2',
#  '358_5633_seg.tif',
#  '364_5634_dem.tif',
#  '350_5652_dem.tif',
#  '366_5633_rgb.jp2',
#  '357_5636_dem.tif',
#  '344_5657_rgb.jp2',
#  '352_5643_rgb.jp2',
#  '359_5640_dem.tif',
#  '364_5640_seg.tif',
#  '364_5648_seg.tif',
#  '348_5658_rgb.jp2',
#  '364_5647_dem.tif',
#  '357_5639_rgb.jp2',
#  '360_5640_seg.tif',
#  '355_5657_rgb.jp2',
#  '355_5648_dem.tif',
#  '367_5645_seg.tif',
#  '351_5642_rgb.jp2',
#  '349_5660_rgb.jp2',
#  '364_5639_dem.tif',
#  '351_5653_dem.tif',
#  '350_5646_rgb.jp2',
#  '366_5648_seg.tif',
#  '368_5636_rgb.jp2',
#  '368_5636_seg.tif',
#  '357_5640_rgb.jp2',
#  '361_5648_dem.tif',
#  '354_5641_rgb.jp2',
#  '362_5646_rgb.jp2',
#  '358_5638_rgb.jp2',
#  '349_5649_rgb.jp2',
#  '355_5644_rgb.jp2',
#  '364_5642_seg.tif',
#  '357_5643_rgb.jp2',
#  '359_5640_seg.tif',
#  '352_5647_seg.tif',
#  '355_5642_rgb.jp2',
#  '357_5646_seg.tif',
#  '369_5643_rgb.jp2',
#  '354_5640_dem.tif',
#  '348_5655_rgb.jp2',
#  '351_5653_seg.tif',
#  '369_5644_rgb.jp2',
#  '347_5649_rgb.jp2',
#  '345_5657_rgb.jp2',
#  '362_5645_dem.tif',
#  '363_5636_dem.tif',
#  '354_5657_rgb.jp2',
#  '368_5642_rgb.jp2',
#  '369_5638_seg.tif',
#  '356_5649_rgb.jp2',
#  '358_5647_seg.tif',
#  '354_5649_rgb.jp2',
#  '360_5647_seg.tif',
#  '354_5645_rgb.jp2',
#  '365_5651_rgb.jp2',
#  '353_5654_rgb.jp2',
#  '353_5642_seg.tif',
#  '349_5649_dem.tif',
#  '346_5644_dem.tif',
#  '362_5654_seg.tif',
#  '360_5634_rgb.jp2',
#  '355_5655_dem.tif',
#  '348_5656_seg.tif',
#  '356_5644_dem.tif',
#  '351_5651_dem.tif',
#  '369_5644_dem.tif',
#  '363_5638_rgb.jp2',
#  '358_5644_rgb.jp2',
#  '356_5650_dem.tif',
#  '364_5633_rgb.jp2',
#  '349_5657_rgb.jp2',
#  '363_5645_seg.tif',
#  '356_5634_seg.tif',
#  '362_5647_dem.tif',
#  '369_5640_dem.tif',
#  '353_5638_seg.tif',
#  '357_5654_seg.tif',
#  '362_5651_rgb.jp2',
#  '358_5639_seg.tif',
#  '362_5650_seg.tif',
#  '348_5659_seg.tif',
#  '351_5654_seg.tif',
#  '356_5652_seg.tif',
#  '351_5650_seg.tif',
#  '363_5639_seg.tif',
#  '360_5648_dem.tif',
#  '358_5642_seg.tif',
#  '354_5639_seg.tif',
#  '353_5634_seg.tif',
#  '358_5650_seg.tif',
#  '350_5651_dem.tif',
#  '361_5636_dem.tif',
#  '360_5633_seg.tif',
#  '355_5642_seg.tif',
#  '347_5647_rgb.jp2',
#  '346_5658_rgb.jp2',
#  '367_5640_rgb.jp2',
#  '353_5639_rgb.jp2',
#  '367_5641_dem.tif',
#  '362_5652_rgb.jp2',
#  '351_5658_dem.tif',
#  '359_5641_dem.tif',
#  '355_5646_rgb.jp2',
#  '359_5644_seg.tif',
#  '367_5634_rgb.jp2',
#  '348_5641_rgb.jp2',
#  '353_5637_dem.tif',
#  '363_5651_dem.tif',
#  '362_5650_dem.tif',
#  '370_5636_seg.tif',
#  '363_5642_dem.tif',
#  '355_5633_seg.tif',
#  '366_5650_dem.tif',
#  '370_5637_rgb.jp2',
#  '359_5639_dem.tif',
#  '356_5645_rgb.jp2',
#  '349_5643_dem.tif',
#  '356_5652_rgb.jp2',
#  '364_5639_rgb.jp2',
#  '344_5658_rgb.jp2',
#  '354_5654_dem.tif',
#  '348_5644_seg.tif',
#  '345_5657_dem.tif',
#  '353_5653_dem.tif',
#  '350_5658_dem.tif',
#  '352_5653_dem.tif',
#  '362_5644_seg.tif',
#  '353_5635_dem.tif',
#  '351_5651_rgb.jp2',
#  '359_5634_dem.tif',
#  '366_5636_dem.tif',
#  '364_5641_dem.tif',
#  '350_5655_dem.tif',
#  '354_5652_dem.tif',
#  '359_5638_dem.tif',
#  '350_5657_seg.tif',
#  '349_5645_dem.tif',
#  '367_5643_rgb.jp2',
#  '358_5645_rgb.jp2',
#  '369_5636_dem.tif',
#  '368_5645_seg.tif',
#  '355_5653_seg.tif',
#  '356_5642_rgb.jp2',
#  '350_5649_seg.tif',
#  '356_5636_rgb.jp2',
#  '344_5659_dem.tif',
#  '363_5653_dem.tif',
#  '357_5650_rgb.jp2',
#  '346_5647_dem.tif',
#  '348_5657_seg.tif',
#  '362_5636_seg.tif',
#  '358_5649_seg.tif',
#  '365_5638_rgb.jp2',
#  '349_5661_seg.tif',
#  '354_5647_dem.tif',
#  '353_5652_rgb.jp2',
#  '356_5637_rgb.jp2',
#  '366_5641_rgb.jp2',
#  '360_5641_seg.tif',
#  '361_5652_dem.tif',
#  '363_5653_seg.tif',
#  '360_5634_seg.tif',
#  '363_5634_dem.tif',
#  '352_5644_rgb.jp2',
#  '362_5635_rgb.jp2',
#  '356_5637_dem.tif',
#  '357_5651_rgb.jp2',
#  '354_5658_rgb.jp2',
#  '364_5642_rgb.jp2',
#  '352_5641_rgb.jp2',
#  '357_5638_seg.tif',
#  '352_5646_dem.tif',
#  '359_5634_rgb.jp2',
#  '368_5635_rgb.jp2',
#  '347_5644_dem.tif',
#  '354_5651_rgb.jp2',
#  '350_5644_dem.tif',
#  '358_5643_seg.tif',
#  '347_5655_seg.tif',
#  '363_5641_dem.tif',
#  '354_5643_dem.tif',
#  '367_5640_seg.tif',
#  '354_5648_dem.tif',
#  '355_5653_rgb.jp2',
#  '366_5640_dem.tif',
#  '350_5651_seg.tif',
#  '356_5648_dem.tif',
#  '369_5637_dem.tif',
#  '359_5652_dem.tif',
#  '364_5653_rgb.jp2',
#  '356_5647_seg.tif',
#  '359_5650_rgb.jp2',
#  '367_5639_seg.tif',
#  '366_5637_dem.tif',
#  '362_5641_dem.tif',
#  '366_5650_rgb.jp2',
#  '353_5652_dem.tif',
#  '369_5636_seg.tif',
#  '346_5645_seg.tif',
#  '354_5641_dem.tif',
#  '358_5651_seg.tif',
#  '361_5639_rgb.jp2',
#  '355_5649_rgb.jp2',
#  '365_5637_dem.tif',
#  '359_5635_rgb.jp2',
#  '361_5653_dem.tif',
#  '354_5635_seg.tif',
#  '357_5647_seg.tif',
#  '362_5640_dem.tif',
#  '358_5645_seg.tif',
#  '349_5646_seg.tif',
#  '354_5644_dem.tif',
#  '355_5645_dem.tif',
#  '349_5659_dem.tif',
#  '355_5638_rgb.jp2',
#  '354_5646_seg.tif',
#  '363_5635_rgb.jp2',
#  '365_5645_rgb.jp2',
#  '368_5644_dem.tif',
#  '356_5643_seg.tif',
#  '362_5649_seg.tif',
#  '351_5655_dem.tif',
#  '356_5636_seg.tif',
#  '361_5634_dem.tif',
#  '357_5655_seg.tif',
#  '348_5653_seg.tif',
#  '344_5659_seg.tif',
#  '353_5635_rgb.jp2',
#  '357_5648_seg.tif',
#  '347_5648_dem.tif',
#  '363_5643_seg.tif',
#  '363_5643_rgb.jp2',
#  '349_5646_dem.tif',
#  '352_5640_dem.tif',
#  '359_5650_seg.tif',
#  '358_5633_rgb.jp2',
#  '353_5658_seg.tif',
#  '364_5633_seg.tif',
#  '347_5644_rgb.jp2',
#  '352_5643_dem.tif',
#  '361_5638_rgb.jp2',
#  '355_5633_rgb.jp2',
#  '354_5653_seg.tif',
#  '356_5656_seg.tif',
#  '349_5642_rgb.jp2',
#  '361_5639_dem.tif',
#  '362_5640_seg.tif',
#  '352_5655_rgb.jp2',
#  '362_5649_dem.tif',
#  '367_5644_dem.tif',
#  '363_5645_rgb.jp2',
#  '348_5646_seg.tif',
#  '352_5651_seg.tif',
#  '364_5651_dem.tif',
#  '350_5657_dem.tif',
#  '359_5635_seg.tif',
#  '349_5653_rgb.jp2',
#  '368_5640_rgb.jp2',
#  '346_5648_seg.tif',
#  '348_5655_dem.tif',
#  '364_5650_rgb.jp2',
#  '346_5646_rgb.jp2',
#  '346_5656_seg.tif',
#  '351_5650_dem.tif',
#  '350_5642_dem.tif',
#  '359_5648_dem.tif',
#  '365_5637_rgb.jp2',
#  '348_5644_rgb.jp2',
#  '356_5638_seg.tif',
#  '358_5641_dem.tif',
#  '365_5635_dem.tif',
#  '353_5648_rgb.jp2',
#  '354_5645_dem.tif',
#  '349_5644_dem.tif',
#  '360_5638_rgb.jp2',
#  '369_5640_rgb.jp2',
#  '353_5656_seg.tif',
#  '354_5654_rgb.jp2',
#  '364_5632_rgb.jp2',
#  '348_5660_rgb.jp2',
#  '349_5643_seg.tif',
#  '356_5640_dem.tif',
#  '365_5636_seg.tif',
#  '362_5645_rgb.jp2',
#  '365_5636_rgb.jp2',
#  '347_5646_rgb.jp2',
#  '352_5646_rgb.jp2',
#  '365_5642_seg.tif',
#  '349_5648_dem.tif',
#  '369_5642_dem.tif',
#  '351_5647_seg.tif',
#  '357_5644_rgb.jp2',
#  '353_5646_rgb.jp2',
#  '354_5654_seg.tif',
#  '365_5640_rgb.jp2',
#  '369_5641_dem.tif',
#  '353_5657_dem.tif',
#  '353_5649_seg.tif',
#  '352_5652_dem.tif',
#  '352_5643_seg.tif',
#  '360_5643_seg.tif',
#  '352_5649_dem.tif',
#  '349_5642_seg.tif',
#  '353_5651_rgb.jp2',
#  '358_5652_seg.tif',
#  '356_5652_dem.tif',
#  '351_5641_seg.tif',
#  '363_5650_rgb.jp2',
#  '353_5641_rgb.jp2',
#  '346_5645_dem.tif',
#  '356_5654_rgb.jp2',
#  '369_5637_rgb.jp2',
#  '363_5639_dem.tif',
#  '359_5636_dem.tif',
#  '358_5651_rgb.jp2',
#  '357_5635_seg.tif',
#  '346_5657_seg.tif',
#  '366_5642_rgb.jp2',
#  '355_5651_rgb.jp2',
#  '367_5644_seg.tif',
#  '365_5644_rgb.jp2',
#  '355_5654_seg.tif',
#  '359_5633_rgb.jp2',
#  '369_5635_seg.tif',
#  '348_5661_dem.tif',
#  '355_5657_dem.tif',
#  '355_5635_dem.tif',
#  '356_5649_seg.tif',
#  '360_5640_rgb.jp2',
#  '366_5642_seg.tif',
#  '355_5637_dem.tif',
#  '350_5654_dem.tif',
#  '362_5643_seg.tif',
#  '355_5650_seg.tif',
#  '345_5659_rgb.jp2',
#  '350_5643_rgb.jp2',
#  '363_5652_seg.tif',
#  '360_5635_dem.tif',
#  '355_5640_dem.tif',
#  '355_5654_dem.tif',
#  '366_5633_seg.tif',
#  '359_5633_dem.tif',
#  '348_5652_rgb.jp2',
#  '366_5646_dem.tif',
#  '365_5634_seg.tif',
#  '361_5653_seg.tif',
#  '361_5642_rgb.jp2',
#  '367_5639_dem.tif',
#  '357_5638_dem.tif',
#  '356_5648_seg.tif',
#  '348_5647_rgb.jp2',
#  '350_5657_rgb.jp2',
#  '362_5651_seg.tif',
#  '349_5652_rgb.jp2',
#  '355_5635_seg.tif',
#  '354_5640_seg.tif',
#  '348_5646_rgb.jp2',
#  '360_5651_dem.tif',
#  '366_5636_rgb.jp2',
#  '355_5650_dem.tif',
#  '360_5635_seg.tif',
#  '353_5657_rgb.jp2',
#  '347_5660_dem.tif',
#  '365_5646_rgb.jp2',
#  '349_5646_rgb.jp2',
#  '349_5660_seg.tif',
#  '357_5640_dem.tif',
#  '345_5658_dem.tif',
#  '356_5653_rgb.jp2',
#  '356_5643_dem.tif',
#  '358_5637_seg.tif',
#  '361_5652_rgb.jp2',
#  '361_5642_seg.tif',
#  '359_5644_dem.tif',
#  '349_5653_dem.tif',
#  '347_5656_seg.tif',
#  '356_5638_rgb.jp2',
#  '354_5651_seg.tif',
#  '347_5658_dem.tif',
#  '354_5642_rgb.jp2',
#  '365_5632_dem.tif',
#  '350_5659_dem.tif',
#  '364_5638_seg.tif',
#  '359_5647_rgb.jp2',
#  '354_5634_rgb.jp2',
#  '359_5641_seg.tif',
#  '351_5645_dem.tif',
#  '368_5634_dem.tif',
#  '350_5656_rgb.jp2',
#  '357_5637_dem.tif',
#  '350_5646_dem.tif',
#  '361_5651_dem.tif',
#  '351_5652_rgb.jp2',
#  '354_5640_rgb.jp2',
#  '365_5634_dem.tif',
#  '343_5659_dem.tif',
#  '368_5643_dem.tif',
#  '369_5637_seg.tif',
#  '346_5645_rgb.jp2',
#  '358_5638_dem.tif',
#  '363_5632_dem.tif',
#  '360_5643_rgb.jp2',
#  '362_5639_rgb.jp2',
#  '352_5655_seg.tif',
#  '362_5644_rgb.jp2',
#  '367_5642_seg.tif',
#  '350_5655_seg.tif',
#  '357_5653_dem.tif',
#  '367_5638_rgb.jp2',
#  '355_5641_seg.tif',
#  '347_5646_dem.tif',
#  '348_5643_dem.tif',
#  '363_5642_seg.tif',
#  '365_5647_rgb.jp2',
#  '365_5642_dem.tif',
#  '368_5644_rgb.jp2',
#  '355_5647_dem.tif',
#  '362_5637_seg.tif',
#  '363_5652_rgb.jp2',
#  '369_5639_dem.tif',
#  '356_5637_seg.tif',
#  '351_5641_dem.tif',
#  '360_5638_dem.tif',
#  '354_5650_rgb.jp2',
#  '348_5652_dem.tif',
#  '360_5648_rgb.jp2',
#  '351_5658_rgb.jp2',
#  '357_5636_rgb.jp2',
#  '358_5646_rgb.jp2',
#  '348_5645_dem.tif',
#  '361_5641_dem.tif',
#  '358_5643_rgb.jp2',
#  '349_5651_seg.tif',
#  '353_5639_seg.tif',
#  '358_5647_rgb.jp2',
#  '349_5657_seg.tif',
#  '365_5647_seg.tif',
#  '350_5644_rgb.jp2',
#  '359_5652_rgb.jp2',
#  '359_5634_seg.tif',
#  '362_5651_dem.tif',
#  '350_5649_rgb.jp2',
#  '367_5641_seg.tif',
#  '369_5641_seg.tif',
#  '353_5649_rgb.jp2',
#  '363_5638_dem.tif',
#  '353_5658_dem.tif',
#  '349_5658_dem.tif',
#  '358_5653_dem.tif',
#  '361_5635_rgb.jp2',
#  '353_5650_rgb.jp2',
#  '351_5642_seg.tif',
#  '366_5639_dem.tif',
#  '367_5633_dem.tif',
#  '346_5657_dem.tif',
#  '370_5637_seg.tif',
#  '365_5649_dem.tif',
#  '364_5651_seg.tif',
#  '357_5652_rgb.jp2',
#  '366_5645_dem.tif',
#  '362_5644_dem.tif',
#  '352_5654_rgb.jp2',
#  '352_5650_rgb.jp2',
#  '353_5647_dem.tif',
#  '348_5648_rgb.jp2',
#  '361_5634_rgb.jp2',
#  '348_5646_dem.tif',
#  '359_5638_seg.tif',
#  '368_5637_dem.tif',
#  '344_5657_seg.tif',
#  '360_5645_dem.tif',
#  '369_5642_rgb.jp2',
#  '362_5645_seg.tif',
#  '355_5649_dem.tif',
#  '354_5635_dem.tif',
#  '366_5646_seg.tif',
#  '364_5643_dem.tif',
#  '366_5644_dem.tif',
#  '348_5649_rgb.jp2',
#  '352_5641_seg.tif',
#  '365_5651_seg.tif',
#  '355_5645_rgb.jp2',
#  '359_5641_rgb.jp2',
#  '362_5638_dem.tif',
#  '361_5653_rgb.jp2',
#  '344_5657_dem.tif',
#  '361_5636_rgb.jp2',
#  '363_5650_dem.tif',
#  '368_5639_seg.tif',
#  '352_5659_rgb.jp2',
#  '366_5649_rgb.jp2',
#  '357_5654_rgb.jp2',
#  '355_5645_seg.tif',
#  '349_5653_seg.tif',
#  '354_5648_seg.tif',
#  '354_5650_dem.tif',
#  '353_5639_dem.tif',
#  '368_5642_seg.tif',
#  '349_5650_rgb.jp2',
#  '360_5640_dem.tif',
#  '348_5643_seg.tif',
#  '348_5642_dem.tif',
#  '360_5653_seg.tif',
#  '355_5634_dem.tif',
#  '366_5644_rgb.jp2',
#  '354_5647_seg.tif',
#  '357_5637_rgb.jp2',
#  '366_5650_seg.tif',
#  '359_5648_rgb.jp2',
#  '348_5658_seg.tif',
#  '365_5634_rgb.jp2',
#  '361_5650_dem.tif',
#  '366_5641_dem.tif',
#  '357_5644_seg.tif',
#  '347_5658_rgb.jp2',
#  '361_5635_dem.tif',
#  '365_5644_dem.tif',
#  '359_5646_dem.tif',
#  '367_5637_dem.tif',
#  '369_5643_seg.tif',
#  '356_5639_seg.tif',
#  '359_5645_seg.tif',
#  '363_5643_dem.tif',
#  '348_5651_seg.tif',
#  '352_5653_rgb.jp2',
#  '355_5657_seg.tif',
#  '363_5652_dem.tif',
#  '359_5649_dem.tif',
#  '363_5637_dem.tif',
#  '359_5651_dem.tif',
#  ...]

# %%
files = glob.glob(os.path.join(DIR,"*_rgb.png"))

SIZE = len(files)

geonrw = tf.data.Dataset.list_files(files)
geonrw = geonrw.shuffle(SIZE)
geonrw = geonrw.map(parse_image)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [17], in <cell line: 5>()
#       1 files = glob.glob(os.path.join(DIR,"*_rgb.png"))
#       3 SIZE = len(files)
# ----> 5 geonrw = tf.data.Dataset.list_files(files)
#       6 geonrw = geonrw.shuffle(SIZE)
#       7 geonrw = geonrw.map(parse_image)
#
# File ~/venv/musa650-final/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:1072, in DatasetV2.list_files(file_pattern, shuffle, seed)
#    1065 condition = math_ops.greater(array_ops.shape(matching_files)[0], 0,
#    1066                              name="match_not_empty")
#    1068 message = math_ops.add(
#    1069     "No files matched pattern: ",
#    1070     string_ops.reduce_join(file_pattern, separator=", "), name="message")
# -> 1072 assert_not_empty = control_flow_ops.Assert(
#    1073     condition, [message], summarize=1, name="assert_not_empty")
#    1074 with ops.control_dependencies([assert_not_empty]):
#    1075   matching_files = array_ops.identity(matching_files)
#
# File ~/venv/musa650-final/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py:235, in should_use_result.<locals>.decorated.<locals>.wrapped(*args, **kwargs)
#     234 def wrapped(*args, **kwargs):
# --> 235   return _add_should_use_warning(fn(*args, **kwargs),
#     236                                  warn_in_eager=warn_in_eager,
#     237                                  error_in_function=error_in_function)
#
# File ~/venv/musa650-final/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:152, in Assert(condition, data, summarize, name)
#     150     xs = ops.convert_n_to_tensor(data)
#     151     data_str = [_summarize_eager(x, summarize) for x in xs]
# --> 152     raise errors.InvalidArgumentError(
#     153         node_def=None,
#     154         op=None,
#     155         message="Expected '%s' to be true. Summarized data: %s" %
#     156         (condition, "\n".join(data_str)))
#     157   return
#     159 with ops.name_scope(name, "Assert", [condition, data]) as name:
#
# InvalidArgumentError: Expected 'tf.Tensor(False, shape=(), dtype=bool)' to be true. Summarized data: b'No files matched pattern: '
